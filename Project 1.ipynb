# %%
import pandas as pd
import numpy as np

# %%
#Our goal is to sort the data and validate if any attributes of the diamond affects its price.

# %%
diamond_df = pd.read_csv("1week_MayDatabootcamp/datasets/diamonds.csv")
diamond_df.head()
#Diamond color ranges from  D to J
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
diamond_df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
diamond_df.min()
# Out:
# Unnamed: 0       1
# carat          0.2
# cut           Fair
# color            D
# clarity         I1
# depth           43
# table           43
# price          326
# x                0
# y                0
# z                0
# dtype: object

# %%
diamond_df.max()
# Out:
# Unnamed: 0        53940
# carat              5.01
# cut           Very Good
# color                 J
# clarity            VVS2
# depth                79
# table                95
# price             18823
# x                 10.74
# y                  58.9
# z                  31.8
# dtype: object

# %%
diamond_df.plot.hist()

# %%
diamond_df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
diamond_nodup = diamond_df.drop_duplicates()
diamond_nodup
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
diamond_df['price'].groupby(diamond_df['cut']).mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
#arrange the file with descending order of price
#group the data by cut and see how expensive they are
#what makes the price of the diamond increase?(cut, color or clarity?)
#does a bigger diamond have a higher price?

# %%
diamond_df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
diamond_df.sort_values('price', ascending = False)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27745       27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95
# 27744       27745   2.29    Premium     I     SI1   61.8   59.0  18797  8.52
# 27742       27743   2.04    Premium     H     SI1   58.1   60.0  18795  8.37
# 27743       27744   2.00    Premium     I     VS1   60.8   59.0  18795  8.13
# 27740       27741   1.71    Premium     F     VS2   62.3   59.0  18791  7.57
# 27741       27742   2.15      Ideal     G     SI2   62.6   54.0  18791  8.29
# 27739       27740   2.80       Good     G     SI2   63.8   58.0  18788  8.90
# ...

# %%
diamond_df['price'].groupby(diamond_df['color']).mean()
# Out:
# color
# D    3169.954096
# E    3076.752475
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %%
#Making a table with carat,cut,color and price

pd.pivot_table(diamond_df, values=['price'], index=['cut','color'])
# Out:
#                        price
# cut       color
# Fair      D      4291.061350
#           E      3682.312500
#           F      3827.003205
#           G      4239.254777
#           H      5135.683168
#           I      4685.445714
#           J      4975.655462
# Good      D      3405.382175
#           E      3423.644159
#           F      3495.750275
#           G      4123.482204
#           H      4276.254986
#           I      5078.532567
#           J      4574.172638
# Ideal     D      2629.094566
#           E      2597.550090
#           F      3374.939362
#           G      3720.706388
#           H      3889.334831
#           I      4451.970377
#           J      4918.186384
# Premium   D      3631.292576
#           E      3538.914420
#           F      4324.890176
#           G      4500.742134
#           H      5216.706780
#           I      5946.180672
#           J      6294.591584
# Very Good D      3470.467284
#           E      3214.652083
# ...

# %%
pd.pivot_table(diamond_df, values=['price'], index=['carat'])
# Out:
#               price
# carat
# 0.20     365.166667
# 0.21     380.222222
# 0.22     391.400000
# 0.23     486.143345
# 0.24     505.185039
# 0.25     550.924528
# 0.26     550.897233
# 0.27     574.759657
# 0.28     580.121212
# 0.29     601.192308
# 0.30     680.301843
# 0.31     708.235660
# 0.32     720.144022
# 0.33     765.731707
# 0.34     756.380220
# 0.35     800.676162
# 0.36     781.381119
# 0.37     816.071066
# 0.38     904.441791
# 0.39     922.331658
# 0.40     932.784450
# 0.41     973.627352
# 0.42     994.444759
# 0.43     995.192623
# 0.44    1056.622642
# 0.45    1093.318182
# 0.46    1237.533708
# 0.47    1272.313131
# 0.48    1322.047619
# 0.49    1306.333333
# ...             ...
# 2.64   17407.000000
# 2.65   16314.000000
# 2.66   16991.000000
# 2.67   18686.000000
# 2.68    9042.000000
# 2.70   14341.000000
# 2.71   17146.000000
# 2.72   12088.333333
# 2.74   14385.000000
# 2.75   14285.500000
# 2.77   10424.000000
# 2.80   16909.000000
# 3.00   12378.500000
# ...
