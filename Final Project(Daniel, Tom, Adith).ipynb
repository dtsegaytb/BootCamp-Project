# %% [raw]
# Project 3: Kickstarter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("datasets/Kickstartercombo.csv")
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'name', 'main_category', 'category', 'country',
#        'state', 'goal', 'pledged', 'currency', 'launched', 'deadline',
#        'backers', 'usd pledged', 'usd_goal_real', 'usd_pledged_real'],
#       dtype='object')

# %%
df.drop_duplicates()
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# name                     8
# main_category            0
# category                 0
# country                  0
# state                    0
# goal                     0
# pledged                  0
# currency                 0
# launched                 0
# deadline                 0
# backers                  0
# usd pledged           7594
# usd_goal_real       323750
# usd_pledged_real    323750
# dtype: int64

# %%
#these two columns were removed becuase most of them were NULL values
df_clean = df.drop('usd_pledged_real', axis=1)
df_clean = df_clean.drop('usd_goal_real', axis=1)
df_clean.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged
# ...

# %%
#these two columns were removed because they had no relation to whether or not the idea was successful.
df_clean = df_clean.drop('launched', axis = 1)
df_clean = df_clean.drop('deadline', axis = 1)
#df_clean = df_clean.drop('usd pledged', axis = 1)
df_clean.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency  backers  usd pledged
# 0      GBP        0          0.0
# ...

# %%
#this column did not matter since goal and pledged were in already in the countrys respective currency.
df_clean = df_clean.drop('usd pledged', axis = 1)

# %%
#pd.pivot_table(df_clean, values=['goal'], index=['state','pledged'])

# %%
df_clean.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency  backers
# 0      GBP        0
# 1      USD        3
# ...

# %%
pd.pivot_table(df_clean, values=['backers'], index=['state'])
# Out:
#                backers
# state
# canceled     25.606675
# failed       16.576774
# live         75.498757
# successful  259.115265
# suspended   108.983759
# undefined     0.000000

# %%
df_clean = df_clean.drop('category', axis = 1)

# %%
#df_clean['main_category'].groupby(df['state']).sum()

# %%
df_clean = df_clean.drop('ID', axis = 1)
df_clean.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0                    The Songs of Adelaide & Abullah
# 1           1                                     Where is Hank?
# 2           2  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  Community Film Project: The Art of Neighborhoo...
# 4           4                               Monarch Espresso Bar
#
#   main_category country       state     goal  pledged currency  backers
# 0    Publishing      GB      failed   1000.0      0.0      GBP        0
# 1  Film & Video      US      failed  45000.0    220.0      USD        3
# 2         Music      US      failed   5000.0      1.0      USD        1
# 3  Film & Video      US    canceled  19500.0   1283.0      USD       14
# 4          Food      US  successful  50000.0  52375.0      USD      224

# %%
df_clean = df_clean.drop('Unnamed: 0', axis = 1)

# %%
df_clean.head()
# Out:
#                                                 name main_category country  \
# 0                    The Songs of Adelaide & Abullah    Publishing      GB
# 1                                     Where is Hank?  Film & Video      US
# 2  ToshiCapital Rekordz Needs Help to Complete Album         Music      US
# 3  Community Film Project: The Art of Neighborhoo...  Film & Video      US
# 4                               Monarch Espresso Bar          Food      US
#
#         state     goal  pledged currency  backers
# 0      failed   1000.0      0.0      GBP        0
# 1      failed  45000.0    220.0      USD        3
# 2      failed   5000.0      1.0      USD        1
# 3    canceled  19500.0   1283.0      USD       14
# 4  successful  50000.0  52375.0      USD      224

# %%
df_clean = df_clean.rename(columns = {'main_category': 'category'})
df_clean.head()
# Out:
#                                                 name      category country  \
# 0                    The Songs of Adelaide & Abullah    Publishing      GB
# 1                                     Where is Hank?  Film & Video      US
# 2  ToshiCapital Rekordz Needs Help to Complete Album         Music      US
# 3  Community Film Project: The Art of Neighborhoo...  Film & Video      US
# 4                               Monarch Espresso Bar          Food      US
#
#         state     goal  pledged currency  backers
# 0      failed   1000.0      0.0      GBP        0
# 1      failed  45000.0    220.0      USD        3
# 2      failed   5000.0      1.0      USD        1
# 3    canceled  19500.0   1283.0      USD       14
# 4  successful  50000.0  52375.0      USD      224

# %%
#writer = pd.ExcelWriter('finalproject_data.xlsx', engine='xlsxwriter')
#df_clean.to_excel(writer, sheet_name='Sheet1')
#writer.save()

# %%
df_clean.to_csv('FinalProject_data.csv')
